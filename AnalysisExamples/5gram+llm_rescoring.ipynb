# %%
#to use the language model, make sure you've unzipped the languageModel.tar.gz file
#and have compiled the code in the LanguageModelDecoder folder
baseDir = '/oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20'

# %%
import os
import time
from glob import glob
from pathlib import Path

import numpy as np
from omegaconf import OmegaConf
import tensorflow as tf
from neuralDecoder.neuralSequenceDecoder import NeuralSequenceDecoder
import neuralDecoder.utils.lmDecoderUtils as lmDecoderUtils
# Out:
# /home/groups/henderj/fwillett/code/speechRelease_v3/lib/python3.9/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 3.2.1'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
#evaluate the RNN on the test partition and competitionHoldOut partition
testDirs = ['test','competitionHoldOut']
trueTranscriptions = [[],[]]
decodedTranscriptions = [[],[]]
rnn_outputs = []
for dirIdx in range(2):
    ckptDir = baseDir + '/derived/rnns/baselineRelease'

    args = OmegaConf.load(os.path.join(ckptDir, 'args.yaml'))
    args['loadDir'] = ckptDir
    args['mode'] = 'infer'
    args['loadCheckpointIdx'] = None

    for x in range(len(args['dataset']['datasetProbabilityVal'])):
        args['dataset']['datasetProbabilityVal'][x] = 0.0

    for sessIdx in range(4,19):
        args['dataset']['datasetProbabilityVal'][sessIdx] = 1.0
        args['dataset']['dataDir'][sessIdx] = baseDir+'/derived/tfRecords'
    args['testDir'] = testDirs[dirIdx]

    with tf.device('/CPU:0'):  # Change to GPU:0 to run on GPU
    # Initialize model
        tf.compat.v1.reset_default_graph()
        nsd = NeuralSequenceDecoder(args)

        # Inference
        out = nsd.inference()
        rnn_outputs.append(out)
# Out:
# 2023-09-01 20:21:10.630560: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-01 20:21:13.900118: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 78928 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-80GB, pci bus id: 0000:41:00.0, compute capability: 8.0
# Model: "gru"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 multiple                  28317696
#
#  gru_2 (GRU)                 multiple                  6297600
#
#  gru_3 (GRU)                 multiple                  6297600
#
#  gru_4 (GRU)                 multiple                  6297600
#
#  gru_5 (GRU)                 multiple                  6297600
#
#  dense (Dense)               multiple                  42025
#
# =================================================================
# Total params: 53,551,145
# Trainable params: 53,551,145
# Non-trainable params: 0
# _________________________________________________________________
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.04.28/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.04.28/test
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.05.05/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.05.05/test
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.05.17/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.05.17/test
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.05.19/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.05.19/test
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.05.24/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.05.24/test
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.05.26/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.05.26/test
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.06.02/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.06.02/test
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.06.07/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.06.07/test
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.06.14/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.06.14/test
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.06.16/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.06.16/test
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.06.21/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.06.21/test
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.06.28/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.06.28/test
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.07.05/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.07.05/test
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.07.14/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.07.14/test
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.07.21/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.07.21/test
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.07.27/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.07.27/test
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.08.02/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.08.02/test
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.08.11/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.08.11/test
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.08.13/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.08.13/test
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, None, 256)         65792
#
#  dropout (Dropout)           (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, None, 256)         65792
#
#  dropout_1 (Dropout)         (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, None, 256)         65792
#
#  dropout_2 (Dropout)         (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, None, 256)         65792
#
#  dropout_3 (Dropout)         (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, None, 256)         65792
#
#  dropout_4 (Dropout)         (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, None, 256)         65792
#
#  dropout_5 (Dropout)         (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, None, 256)         65792
#
#  dropout_6 (Dropout)         (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, None, 256)         65792
#
#  dropout_7 (Dropout)         (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, None, 256)         65792
#
#  dropout_8 (Dropout)         (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, None, 256)         65792
#
#  dropout_9 (Dropout)         (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_11 (Dense)            (None, None, 256)         65792
#
#  dropout_10 (Dropout)        (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, None, 256)         65792
#
#  dropout_11 (Dropout)        (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_13 (Dense)            (None, None, 256)         65792
#
#  dropout_12 (Dropout)        (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_14 (Dense)            (None, None, 256)         65792
#
#  dropout_13 (Dropout)        (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, None, 256)         65792
#
#  dropout_14 (Dropout)        (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_16 (Dense)            (None, None, 256)         65792
#
#  dropout_15 (Dropout)        (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_17 (Dense)            (None, None, 256)         65792
#
#  dropout_16 (Dropout)        (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, None, 256)         65792
#
#  dropout_17 (Dropout)        (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_19 (Dense)            (None, None, 256)         65792
#
#  dropout_18 (Dropout)        (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Loading from : /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/rnns/baselineRelease/ckpt-9950
# Model: "gru"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 multiple                  28317696
#
#  gru_2 (GRU)                 multiple                  6297600
#
#  gru_3 (GRU)                 multiple                  6297600
#
#  gru_4 (GRU)                 multiple                  6297600
#
#  gru_5 (GRU)                 multiple                  6297600
#
#  dense (Dense)               multiple                  42025
#
# =================================================================
# Total params: 53,551,145
# Trainable params: 53,551,145
# Non-trainable params: 0
# _________________________________________________________________
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.04.28/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.04.28/competitionHoldOut
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.05.05/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.05.05/competitionHoldOut
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.05.17/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.05.17/competitionHoldOut
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.05.19/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.05.19/competitionHoldOut
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.05.24/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.05.24/competitionHoldOut
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.05.26/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.05.26/competitionHoldOut
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.06.02/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.06.02/competitionHoldOut
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.06.07/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.06.07/competitionHoldOut
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.06.14/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.06.14/competitionHoldOut
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.06.16/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.06.16/competitionHoldOut
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.06.21/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.06.21/competitionHoldOut
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.06.28/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.06.28/competitionHoldOut
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.07.05/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.07.05/competitionHoldOut
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.07.14/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.07.14/competitionHoldOut
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.07.21/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.07.21/competitionHoldOut
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.07.27/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.07.27/competitionHoldOut
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.08.02/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.08.02/competitionHoldOut
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.08.11/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.08.11/competitionHoldOut
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.08.13/train
# Load data from /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/tfRecords/t12.2022.08.13/competitionHoldOut
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, None, 256)         65792
#
#  dropout (Dropout)           (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, None, 256)         65792
#
#  dropout_1 (Dropout)         (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, None, 256)         65792
#
#  dropout_2 (Dropout)         (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, None, 256)         65792
#
#  dropout_3 (Dropout)         (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, None, 256)         65792
#
#  dropout_4 (Dropout)         (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, None, 256)         65792
#
#  dropout_5 (Dropout)         (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, None, 256)         65792
#
#  dropout_6 (Dropout)         (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, None, 256)         65792
#
#  dropout_7 (Dropout)         (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, None, 256)         65792
#
#  dropout_8 (Dropout)         (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, None, 256)         65792
#
#  dropout_9 (Dropout)         (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_11 (Dense)            (None, None, 256)         65792
#
#  dropout_10 (Dropout)        (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, None, 256)         65792
#
#  dropout_11 (Dropout)        (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_13 (Dense)            (None, None, 256)         65792
#
#  dropout_12 (Dropout)        (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_14 (Dense)            (None, None, 256)         65792
#
#  dropout_13 (Dropout)        (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, None, 256)         65792
#
#  dropout_14 (Dropout)        (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_16 (Dense)            (None, None, 256)         65792
#
#  dropout_15 (Dropout)        (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_17 (Dense)            (None, None, 256)         65792
#
#  dropout_16 (Dropout)        (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, None, 256)         65792
#
#  dropout_17 (Dropout)        (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_19 (Dense)            (None, None, 256)         65792
#
#  dropout_18 (Dropout)        (None, None, 256)         0
#
# =================================================================
# Total params: 65,792
# Trainable params: 65,792
# Non-trainable params: 0
# _________________________________________________________________
# Loading from : /oak/stanford/groups/henderj/fwillett/speechPaperRelease_08_20/derived/rnns/baselineRelease/ckpt-9950

# %%
## Load a 5gram model with an unpruned LM
lmDir = baseDir+'/languageModel_5gram'
ngramDecoder = lmDecoderUtils.build_lm_decoder(
    lmDir,
    acoustic_scale=0.5,
    nbest=100,
    beam=18
)

MODEL_CACHE_DIR = '/scratch/users/fwillett/huggingface'
# Load OPT 6B model
llm, llm_tokenizer = lmDecoderUtils.build_opt(cacheDir=MODEL_CACHE_DIR,
                                              device='auto',
                                              load_in_8bit=True
)
# Out:
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# I0901 20:24:53.750929 18719 brain_speech_decoder.h:52] Reading fst /oak/stanford/groups/henderj/fwillett/speech/speech_5gram/lang_test/TLG.fst
# I0901 20:28:30.020897 18719 brain_speech_decoder.h:58] Reading lm fst /oak/stanford/groups/henderj/fwillett/speech/speech_5gram/lang_test/G.fst
# I0901 20:29:15.658622 18719 brain_speech_decoder.h:70] Reading rescore fst /oak/stanford/groups/henderj/fwillett/speech/speech_5gram/lang_test/G_no_prune.fst
# I0901 20:43:37.406898 18719 brain_speech_decoder.h:81] Reading symbol table /oak/stanford/groups/henderj/fwillett/speech/speech_5gram/lang_test/words.txt
# Downloading (…)okenizer_config.json:   0%|          | 0.00/685 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/651 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/441 [00:00<?, ?B/s]
# Overriding torch_dtype=None with `torch_dtype=torch.float16` due to requirements of `bitsandbytes` to enable model loading in mixed int8. Either pass torch_dtype=torch.float16 or don't pass this argument at all to remove this warning.
# Downloading (…)model.bin.index.json:   0%|          | 0.00/41.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)l-00001-of-00002.bin:   0%|          | 0.00/9.96G [00:00<?, ?B/s]
# Downloading (…)l-00002-of-00002.bin:   0%|          | 0.00/3.36G [00:00<?, ?B/s]
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please run
#
# python -m bitsandbytes
#
#  and submit this information together with your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# ================================================================================
# bin /home/groups/henderj/fwillett/code/speechRelease_v3/lib/python3.9/site-packages/bitsandbytes/libbitsandbytes_cuda115.so
# CUDA SETUP: CUDA runtime path found: /share/software/user/open/cuda/11.5.0/lib64/libcudart.so
# CUDA SETUP: Highest compute capability among GPUs detected: 8.0
# CUDA SETUP: Detected CUDA version 115
# CUDA SETUP: Loading binary /home/groups/henderj/fwillett/code/speechRelease_v3/lib/python3.9/site-packages/bitsandbytes/libbitsandbytes_cuda115.so...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]

# %%
# LM decoding hyperparameters
acoustic_scale = 0.5
blank_penalty = np.log(7)
llm_weight = 0.5

llm_outputs = []
for i, out in enumerate(rnn_outputs):
    # Generate nbest outputs from 5gram LM
    start_t = time.time()
    nbest_outputs = []
    logits = lmDecoderUtils.rearrange_speech_logits(out['logits'], has_sil=True)
    logitLengths = out['logitLengths']
    for j in range(len(logits)):
        nbest = lmDecoderUtils.lm_decode(ngramDecoder,
                                         logits[j, :logitLengths[j]],
                                         blankPenalty=blank_penalty,
                                         returnNBest=True,
                                         rescore=True)
        nbest_outputs.append(nbest)
    time_per_sample = (time.time() - start_t) / len(logits)
    print(f'5gram decoding took {time_per_sample} seconds per sample')

    # Rescore nbest outputs with LLM
    start_t = time.time()
    llm_out = lmDecoderUtils.cer_with_gpt2_decoder(llm,
                                                   llm_tokenizer,
                                                   nbest_outputs,
                                                   acoustic_scale,
                                                   out,
                                                   outputType='speech_sil',
                                                   returnCI=True,
                                                   lengthPenalty=0,
                                                   alpha=llm_weight)
    time_per_sample = (time.time() - start_t) / len(logits)
    print(f'LLM decoding took {time_per_sample} seconds per sample')
    if i == 0:
        print(f"Final WER={llm_out['wer']}")
    
    llm_outputs.append(llm_out)
# Out:
# 5gram decoding took 0.4057309754689534 seconds per sample
#   0%|          | 0/600 [00:00<?, ?it/s]
# LLM decoding took 0.34114742080370586 seconds per sample
# Final WER=(0.13715372080391092, 0.12286023812646826, 0.1521934901601293)
# 5gram decoding took 0.2865370541810989 seconds per sample
#   0%|          | 0/1200 [00:00<?, ?it/s]
# LLM decoding took 0.2773782895008723 seconds per sample

# %%
#format the predictions for competition submission. This generates a .txt file that can be submitted.
decodedTranscriptions[dirIdx] = llm_outputs[1]['decoded_transcripts']
with open('/oak/stanford/groups/henderj/fwillett/5gramLLMCompetitionSubmission.txt', 'w') as f:
    for x in range(len(decodedTranscriptions[1])):
        f.write(decodedTranscriptions[1][x]+'\n')
